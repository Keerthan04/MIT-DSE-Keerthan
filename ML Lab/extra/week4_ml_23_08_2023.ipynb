# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
       
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\ml_lab220970023\MLLABWEEK03-DOCS-16AUG2023 (2)\MLLABWEEK03-DOCS-16AUG2023\DATASETS-16AUG2023\ccpp.csv")
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
x=df.drop(['PE'],axis=1).values
x
# Out:
# array([[   8.34,   40.77, 1010.84,   90.01],
#        [  23.64,   58.49, 1011.4 ,   74.2 ],
#        [  29.74,   56.9 , 1007.15,   41.91],
#        ...,
#        [  15.99,   43.34, 1014.2 ,   78.66],
#        [  17.65,   59.87, 1018.58,   94.65],
#        [  23.68,   51.3 , 1011.86,   71.24]])

# %%
y=df['PE'].values
y
# Out:
# array([480.48, 445.75, 438.76, ..., 465.96, 450.93, 451.67])

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=mlr.predict(x_test)
print(y_predict)
# Out:
# [435.84487386 437.44757676 461.25214944 ... 450.97887433 483.40680876
#  435.47926756]

# %%
mlr.predict([[14.96,41.76,1024.07,73.17]])
# Out:
# array([467.2114018])

# %%
r2_score(y_predict,y_test)
# Out:
# 0.9251878660493015

# %%
plt.figure(figsize=(10,30))
plt.scatter(y_test,y_predict)
plt.xlabel("actual values")
plt.ylabel("predicted values")
plt.title("multiple linear regression")
# Out:
# Text(0.5, 1.0, 'multiple linear regression')

# %%
pred_y_df=pd.DataFrame({"actual value":y_test, "predicted_value":y_predict,'Difference':y_test-y_predict})

# %%
pred_y_df[0:20]
# Out:
#     actual value  predicted_value  Difference
# 0         433.27       435.844874   -2.574874
# 1         438.16       437.447577    0.712423
# 2         458.42       461.252149   -2.832149
# 3         480.82       476.059882    4.760118
# 4         441.41       435.811718    5.598282
# 5         454.75       459.226065   -4.476065
# 6         483.26       481.138567    2.121433
# 7         478.25       479.031518   -0.781518
# 8         434.16       439.451419   -5.291419
# 9         470.66       469.903867    0.756133
# 10        450.86       448.221069    2.638931
# 11        455.79       455.043064    0.746936
# 12        489.59       485.638100    3.951900
# 13        471.79       471.412074    0.377926
# 14        480.63       475.541176    5.088824
# 15        432.97       435.132438   -2.162438
# 16        473.34       476.759389   -3.419389
# 17        432.25       435.073155   -2.823155
# 18        429.80       433.188372   -3.388372
# ...

# %%
len(x_train)
len(x_test)
len(y_train)
len(y_test)
# Out:
# 2871
